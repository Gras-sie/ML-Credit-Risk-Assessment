# %%
import pandas as pd

# %%
# Load the datasets from the provided Excel files
credit_risk_1 = pd.read_excel('credit_risk_file_1.xlsx')
credit_risk_2 = pd.read_excel('credit_risk_file_2.xlsx')

# Combine the two datasets into a single DataFrame
credit_risk_data = pd.concat([credit_risk_1, credit_risk_2], ignore_index=True)

# %% [markdown]
# Variable Name	                Description
#
# Total_TL	                    Total trade lines/accounts in Bureau
# Tot_Closed_TL	                Total closed trade lines/accounts
# Tot_Active_TL	                Total active accounts
# Total_TL_opened_L6M	            Total accounts opened in last 6 Months
# Tot_TL_closed_L6M	            Total accounts closed in last 6 months
# pct_tl_open_L6M	                Percent accounts opened in last 6 months
# pct_tl_closed_L6M	            Percent accounts closed in last 6 months
# pct_active_tl	                Percent active accounts
# pct_closed_tl	                Percent closed accounts
# Total_TL_opened_L12M	        Total accounts opened in last 12 Months
# Tot_TL_closed_L12M	            Total accounts closed in last 12 months
# pct_tl_open_L12M	            Percent accounts opened in last 12 months
# pct_tl_closed_L12M	            Percent accounts closed in last 12 months
# Tot_Missed_Pmnt	                Total missed Payments
# Auto_TL	                        Count Automobile accounts
# CC_TL	                        Count of Credit card accounts
# Consumer_TL	                    Count of Consumer goods accounts
# Gold_TL	                        Count of Gold loan accounts
# Home_TL	                        Count of Housing loan accounts
# PL_TL	                        Count of Personal loan accounts
# Secured_TL	                    Count of secured accounts
# Unsecured_TL	                Count of unsecured accounts
# Other_TL	                    Count of other accounts
# Age_Oldest_TL	                Age of oldest opened account
# Age_Newest_TL	                Age of newest opened account

# %%
credit_risk_data.head()
# Out:
#    PROSPECTID  Total_TL  Tot_Closed_TL  Tot_Active_TL  Total_TL_opened_L6M  \
# 0           1       5.0            4.0            1.0                  0.0
# 1           2       1.0            0.0            1.0                  0.0
# 2           3       8.0            0.0            8.0                  1.0
# 3           4       1.0            0.0            1.0                  1.0
# 4           5       3.0            2.0            1.0                  0.0
#
#    Tot_TL_closed_L6M  pct_tl_open_L6M  pct_tl_closed_L6M  pct_active_tl  \
# 0                0.0            0.000                0.0          0.200
# 1                0.0            0.000                0.0          1.000
# 2                0.0            0.125                0.0          1.000
# 3                0.0            1.000                0.0          1.000
# 4                0.0            0.000                0.0          0.333
#
#    pct_closed_tl  ...  pct_CC_enq_L6m_of_L12m  pct_PL_enq_L6m_of_ever  \
# 0          0.800  ...                     NaN                     NaN
# 1          0.000  ...                     NaN                     NaN
# 2          0.000  ...                     NaN                     NaN
# 3          0.000  ...                     NaN                     NaN
# 4          0.667  ...                     NaN                     NaN
#
#    pct_CC_enq_L6m_of_ever  max_unsec_exposure_inPct  HL_Flag  GL_Flag  \
# 0                     NaN                       NaN      NaN      NaN
# 1                     NaN                       NaN      NaN      NaN
# 2                     NaN                       NaN      NaN      NaN
# 3                     NaN                       NaN      NaN      NaN
# 4                     NaN                       NaN      NaN      NaN
#
#    last_prod_enq2  first_prod_enq2  Credit_Score  Approved_Flag
# 0             NaN              NaN           NaN            NaN
# 1             NaN              NaN           NaN            NaN
# 2             NaN              NaN           NaN            NaN
# 3             NaN              NaN           NaN            NaN
# 4             NaN              NaN           NaN            NaN
#
# [5 rows x 87 columns]

# %%
# Display basic information about the DataFrame
print(credit_risk_data.info())

# Check for missing values in the dataset
print(credit_risk_data.isnull().sum())

# Handle missing values by imputation or dropping 
# For numerical columns, fill missing values with the median of the column
for col in credit_risk_data.select_dtypes(include=['float64', 'int64']).columns:
    credit_risk_data[col].fillna(credit_risk_data[col].median(), inplace=True)

# For categorical columns, fill missing values with the mode of the column
for col in credit_risk_data.select_dtypes(include=['object']).columns:
    credit_risk_data[col].fillna(credit_risk_data[col].mode()[0], inplace=True)

# Confirm that there are no more missing values
print(credit_risk_data.isnull().sum())

# Display the first few rows of the DataFrame to verify changes
print(credit_risk_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102672 entries, 0 to 102671
# Data columns (total 87 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   PROSPECTID                    102672 non-null  int64
#  1   Total_TL                      51336 non-null   float64
#  2   Tot_Closed_TL                 51336 non-null   float64
#  3   Tot_Active_TL                 51336 non-null   float64
#  4   Total_TL_opened_L6M           51336 non-null   float64
#  5   Tot_TL_closed_L6M             51336 non-null   float64
#  6   pct_tl_open_L6M               51336 non-null   float64
#  7   pct_tl_closed_L6M             51336 non-null   float64
#  8   pct_active_tl                 51336 non-null   float64
#  9   pct_closed_tl                 51336 non-null   float64
#  10  Total_TL_opened_L12M          51336 non-null   float64
#  11  Tot_TL_closed_L12M            51336 non-null   float64
#  12  pct_tl_open_L12M              51336 non-null   float64
#  13  pct_tl_closed_L12M            51336 non-null   float64
#  14  Tot_Missed_Pmnt               51336 non-null   float64
#  15  Auto_TL                       51336 non-null   float64
#  16  CC_TL                         51336 non-null   float64
#  17  Consumer_TL                   51336 non-null   float64
#  18  Gold_TL                       51336 non-null   float64
#  19  Home_TL                       51336 non-null   float64
#  20  PL_TL                         51336 non-null   float64
#  21  Secured_TL                    51336 non-null   float64
#  22  Unsecured_TL                  51336 non-null   float64
#  23  Other_TL                      51336 non-null   float64
#  24  Age_Oldest_TL                 51336 non-null   float64
#  25  Age_Newest_TL                 51336 non-null   float64
#  26  time_since_recent_payment     51336 non-null   float64
#  27  time_since_first_deliquency   51336 non-null   float64
#  28  time_since_recent_deliquency  51336 non-null   float64
#  29  num_times_delinquent          51336 non-null   float64
#  30  max_delinquency_level         51336 non-null   float64
#  31  max_recent_level_of_deliq     51336 non-null   float64
#  32  num_deliq_6mts                51336 non-null   float64
#  33  num_deliq_12mts               51336 non-null   float64
#  34  num_deliq_6_12mts             51336 non-null   float64
#  35  max_deliq_6mts                51336 non-null   float64
#  36  max_deliq_12mts               51336 non-null   float64
#  37  num_times_30p_dpd             51336 non-null   float64
#  38  num_times_60p_dpd             51336 non-null   float64
#  39  num_std                       51336 non-null   float64
#  40  num_std_6mts                  51336 non-null   float64
#  41  num_std_12mts                 51336 non-null   float64
#  42  num_sub                       51336 non-null   float64
#  43  num_sub_6mts                  51336 non-null   float64
#  44  num_sub_12mts                 51336 non-null   float64
#  45  num_dbt                       51336 non-null   float64
#  46  num_dbt_6mts                  51336 non-null   float64
#  47  num_dbt_12mts                 51336 non-null   float64
#  48  num_lss                       51336 non-null   float64
#  49  num_lss_6mts                  51336 non-null   float64
#  50  num_lss_12mts                 51336 non-null   float64
#  51  recent_level_of_deliq         51336 non-null   float64
#  52  tot_enq                       51336 non-null   float64
#  53  CC_enq                        51336 non-null   float64
#  54  CC_enq_L6m                    51336 non-null   float64
#  55  CC_enq_L12m                   51336 non-null   float64
#  56  PL_enq                        51336 non-null   float64
#  57  PL_enq_L6m                    51336 non-null   float64
#  58  PL_enq_L12m                   51336 non-null   float64
#  59  time_since_recent_enq         51336 non-null   float64
#  60  enq_L12m                      51336 non-null   float64
#  61  enq_L6m                       51336 non-null   float64
#  62  enq_L3m                       51336 non-null   float64
#  63  MARITALSTATUS                 51336 non-null   object
#  64  EDUCATION                     51336 non-null   object
#  65  AGE                           51336 non-null   float64
#  66  GENDER                        51336 non-null   object
#  67  NETMONTHLYINCOME              51336 non-null   float64
#  68  Time_With_Curr_Empr           51336 non-null   float64
#  69  pct_of_active_TLs_ever        51336 non-null   float64
#  70  pct_opened_TLs_L6m_of_L12m    51336 non-null   float64
#  71  pct_currentBal_all_TL         51336 non-null   float64
#  72  CC_utilization                51336 non-null   float64
#  73  CC_Flag                       51336 non-null   float64
#  74  PL_utilization                51336 non-null   float64
#  75  PL_Flag                       51336 non-null   float64
#  76  pct_PL_enq_L6m_of_L12m        51336 non-null   float64
#  77  pct_CC_enq_L6m_of_L12m        51336 non-null   float64
#  78  pct_PL_enq_L6m_of_ever        51336 non-null   float64
#  79  pct_CC_enq_L6m_of_ever        51336 non-null   float64
#  80  max_unsec_exposure_inPct      51336 non-null   float64
#  81  HL_Flag                       51336 non-null   float64
#  82  GL_Flag                       51336 non-null   float64
#  83  last_prod_enq2                51336 non-null   object
#  84  first_prod_enq2               51336 non-null   object
#  85  Credit_Score                  51336 non-null   float64
#  86  Approved_Flag                 51336 non-null   object
# dtypes: float64(80), int64(1), object(6)
# memory usage: 68.1+ MB
# None
# PROSPECTID                 0
# Total_TL               51336
# Tot_Closed_TL          51336
# Tot_Active_TL          51336
# Total_TL_opened_L6M    51336
#                        ...
# GL_Flag                51336
# last_prod_enq2         51336
# first_prod_enq2        51336
# Credit_Score           51336
# Approved_Flag          51336
# Length: 87, dtype: int64
# C:\Users\purnj\AppData\Local\Temp\ipykernel_24440\126705777.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_risk_data[col].fillna(credit_risk_data[col].median(), inplace=True)
# C:\Users\purnj\AppData\Local\Temp\ipykernel_24440\126705777.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   credit_risk_data[col].fillna(credit_risk_data[col].mode()[0], inplace=True)
# PROSPECTID             0
# Total_TL               0
# Tot_Closed_TL          0
# Tot_Active_TL          0
# Total_TL_opened_L6M    0
#                       ..
# GL_Flag                0
# last_prod_enq2         0
# first_prod_enq2        0
# Credit_Score           0
# Approved_Flag          0
# Length: 87, dtype: int64
#    PROSPECTID  Total_TL  Tot_Closed_TL  Tot_Active_TL  Total_TL_opened_L6M  \
# 0           1       5.0            4.0            1.0                  0.0
# 1           2       1.0            0.0            1.0                  0.0
# 2           3       8.0            0.0            8.0                  1.0
# 3           4       1.0            0.0            1.0                  1.0
# 4           5       3.0            2.0            1.0                  0.0
#
#    Tot_TL_closed_L6M  pct_tl_open_L6M  pct_tl_closed_L6M  pct_active_tl  \
# 0                0.0            0.000                0.0          0.200
# 1                0.0            0.000                0.0          1.000
# 2                0.0            0.125                0.0          1.000
# 3                0.0            1.000                0.0          1.000
# 4                0.0            0.000                0.0          0.333
#
#    pct_closed_tl  ...  pct_CC_enq_L6m_of_L12m  pct_PL_enq_L6m_of_ever  \
# 0          0.800  ...                     0.0                     0.0
# 1          0.000  ...                     0.0                     0.0
# 2          0.000  ...                     0.0                     0.0
# 3          0.000  ...                     0.0                     0.0
# 4          0.667  ...                     0.0                     0.0
#
#    pct_CC_enq_L6m_of_ever  max_unsec_exposure_inPct  HL_Flag  GL_Flag  \
# 0                     0.0                     0.333      0.0      0.0
# 1                     0.0                     0.333      0.0      0.0
# 2                     0.0                     0.333      0.0      0.0
# 3                     0.0                     0.333      0.0      0.0
# 4                     0.0                     0.333      0.0      0.0
#
#    last_prod_enq2  first_prod_enq2  Credit_Score  Approved_Flag
# 0          others           others         680.0             P2
# 1          others           others         680.0             P2
# 2          others           others         680.0             P2
# 3          others           others         680.0             P2
# 4          others           others         680.0             P2
#
# [5 rows x 87 columns]

# %%
# Analyzing data types and distributions of the target variable
import matplotlib.pyplot as plt
import seaborn as sns

# Display data types of each column
data_types = credit_risk_data.dtypes
print("Data Types of Each Column:")
print(data_types)

# Analyze the distribution of the target variable "Approved_Flag"
plt.figure(figsize=(8, 4))
sns.countplot(x='Approved_Flag', data=credit_risk_data)
plt.title('Distribution of Approved_Flag')
plt.xlabel('Approved Flag')
plt.ylabel('Count')
plt.show()

# Display the proportion of approved and rejected applications
approved_counts = credit_risk_data['Approved_Flag'].value_counts(normalize=True)
print("Proportion of Approved and Rejected Applications:")
print(approved_counts)
# Out:
# Data Types of Each Column:
# PROSPECTID               int64
# Total_TL               float64
# Tot_Closed_TL          float64
# Tot_Active_TL          float64
# Total_TL_opened_L6M    float64
#                         ...
# GL_Flag                float64
# last_prod_enq2          object
# first_prod_enq2         object
# Credit_Score           float64
# Approved_Flag           object
# Length: 87, dtype: object
# Proportion of Approved and Rejected Applications:
# Approved_Flag
# P2    0.813610
# P3    0.072581
# P4    0.057289
# P1    0.056520
# Name: proportion, dtype: float64

# %%
# Selecting numerical and categorical columns for analysis
numerical_cols = credit_risk_data.select_dtypes(include=['float64', 'int64']).columns
categorical_cols = credit_risk_data.select_dtypes(include=['object']).columns

# Calculate the number of rows needed for subplots based on the number of numerical columns
num_rows = (len(numerical_cols) - 1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(20, num_rows * 4))  

for i, col in enumerate(numerical_cols):
    plt.subplot(num_rows, 5, i + 1)
    sns.histplot(credit_risk_data[col], kde=True) 
    plt.title(f'Distribution of {col}', fontsize=14, fontweight='bold') 
    plt.xlabel(col, fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.grid(axis='y', linestyle='--', alpha=0.7) 
    sns.despine() 
    plt.tight_layout(rect=[0, 0.03, 1, 0.95]) 

plt.suptitle('Histograms of Numerical Features', fontsize=20, fontweight='bold') 
plt.show()

# %%
# Display box plots for numerical features to identify outliers

plt.figure(figsize=(20, num_rows * 4)) 

for i, col in enumerate(numerical_cols):
    plt.subplot(num_rows, 5, i + 1)
    sns.boxplot(x='Approved_Flag', y=col, data=credit_risk_data) 
    plt.title(col, fontsize=14, fontweight='bold') 
    plt.xlabel('Application Approved', fontsize=12)
    plt.ylabel(col, fontsize=12)
    sns.despine() 
    plt.tight_layout() 
plt.show()

# %%
# Analyzing categorical variables with respect to the target variable
num_rows_cat = (len(categorical_cols) - 1) // 5 + 1
plt.figure(figsize=(20, num_rows_cat * 3))
for i, col in enumerate(categorical_cols):
    if col != 'Approved_Flag':  # Exclude the target variable itself
        plt.subplot(num_rows_cat, 5, i + 1)
        sns.countplot(x=col, hue='Approved_Flag', data=credit_risk_data)
        plt.title(col)
        plt.grid(axis='y', linestyle='--', alpha=0.7) 
        plt.xticks(rotation=45)
        plt.tight_layout()
plt.show()

# %%
# Correlation matrix for numerical features
import matplotlib.pyplot as plt  
import seaborn as sns 

correlation_matrix = credit_risk_data[numerical_cols].corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, fmt=".2f", cmap='plasma')
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
# Scatter plots to explore relationships between some selected numerical features and the target
# Selecting a few potentially interesting numerical features for scatter plots
selected_features = ['Total_TL', 'Tot_Active_TL', 'Credit_Score', 'max_unsec_exposure_inPct']
plt.figure(figsize=(15, 10))
for i, col in enumerate(selected_features):
    plt.subplot(2, 2, i + 1)
    sns.scatterplot(x=col, y='Credit_Score', hue='Approved_Flag', data=credit_risk_data)
    plt.title(f'Relationship between {col} and Credit Score by Approval Status')
    plt.grid(axis='y', linestyle='--', alpha=0.7) 
    plt.tight_layout()
plt.show()

# %%
# Copy the DataFrame for processing
credit_risk_fe = credit_risk_data.copy()

# Remove the ID column as it is not useful for modeling
credit_risk_fe.drop('PROSPECTID', axis=1, inplace=True)

# %%
# Feature Engineering: Creating new features

# 1. Ratios of different types of credit accounts
credit_risk_fe['Secured_to_Unsecured_Ratio'] = credit_risk_fe['Secured_TL'] / (credit_risk_fe['Unsecured_TL'] + 0.01)
credit_risk_fe['Active_to_Closed_TL_Ratio'] = credit_risk_fe['Tot_Active_TL'] / (credit_risk_fe['Tot_Closed_TL'] + 0.01)

# 2. Debt-to-income ratio (assuming 'NETMONTHLYINCOME' is monthly income and 'pct_currentBal_all_TL' is the percentage of total loan to income)
credit_risk_fe['Debt_to_Income_Ratio'] = credit_risk_fe['pct_currentBal_all_TL'] / (credit_risk_fe['NETMONTHLYINCOME'] + 0.01)

# 3. Time since last delinquency as a proportion of credit history length
credit_risk_fe['Delinquency_to_Credit_History_Ratio'] = credit_risk_fe['time_since_recent_deliquency'] / (credit_risk_fe['Age_Oldest_TL'] + 0.01)

# 4. Interaction terms between relevant features
credit_risk_fe['Interaction_Credit_Score_Unsec_Exposure'] = credit_risk_fe['Credit_Score'] * credit_risk_fe['max_unsec_exposure_inPct']
credit_risk_fe['Interaction_Income_Credit_Score'] = credit_risk_fe['NETMONTHLYINCOME'] * credit_risk_fe['Credit_Score']

# %%
# Display the head of the DataFrame to check the new features
credit_risk_fe.head()
# Out:
#    Total_TL  Tot_Closed_TL  Tot_Active_TL  Total_TL_opened_L6M  \
# 0       5.0            4.0            1.0                  0.0
# 1       1.0            0.0            1.0                  0.0
# 2       8.0            0.0            8.0                  1.0
# 3       1.0            0.0            1.0                  1.0
# 4       3.0            2.0            1.0                  0.0
#
#    Tot_TL_closed_L6M  pct_tl_open_L6M  pct_tl_closed_L6M  pct_active_tl  \
# 0                0.0            0.000                0.0          0.200
# 1                0.0            0.000                0.0          1.000
# 2                0.0            0.125                0.0          1.000
# 3                0.0            1.000                0.0          1.000
# 4                0.0            0.000                0.0          0.333
#
#    pct_closed_tl  Total_TL_opened_L12M  ...  last_prod_enq2  first_prod_enq2  \
# 0          0.800                   0.0  ...          others           others
# 1          0.000                   1.0  ...          others           others
# 2          0.000                   2.0  ...          others           others
# 3          0.000                   1.0  ...          others           others
# 4          0.667                   0.0  ...          others           others
#
#    Credit_Score  Approved_Flag  Secured_to_Unsecured_Ratio  \
# 0         680.0             P2                    0.249377
# 1         680.0             P2                    0.000000
# 2         680.0             P2                    0.332779
# 3         680.0             P2                    0.000000
# 4         680.0             P2                  300.000000
#
#    Active_to_Closed_TL_Ratio  Debt_to_Income_Ratio  \
# 0                   0.249377              0.000027
# 1                 100.000000              0.000027
# 2                 800.000000              0.000027
# 3                 100.000000              0.000027
# 4                   0.497512              0.000027
#
#    Delinquency_to_Credit_History_Ratio  \
# 0                         -1388.682127
# 1                        -14265.192582
# 2                         -2127.185705
# 3                        -19959.880240
# 4                          -763.292878
#
#    Interaction_Credit_Score_Unsec_Exposure  Interaction_Income_Credit_Score
# 0                                   226.44                       15640000.0
# 1                                   226.44                       15640000.0
# 2                                   226.44                       15640000.0
# 3                                   226.44                       15640000.0
# 4                                   226.44                       15640000.0
#
# [5 rows x 92 columns]

# %%
# Export to a CSV file
credit_risk_fe.to_csv('credit_risk_features.csv', index=False)

print("DataFrame successfully exported to credit_risk_features.csv")
# Out:
# DataFrame successfully exported to credit_risk_features.csv
